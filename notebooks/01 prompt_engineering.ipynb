# %%
path_img1 = 'data/test1/IMG_3398.png'
path_img2 = 'data/test1/IMG_3399.png'
path_img3 = 'data/test1/IMG_3410.png'

def prompt_img(input_text, path):
    
    return [{
            'role': 'user',
            'content': input_text,
            'images': [path]
        }]
    
def prompt(input_text):
    
    return [{
            'role': 'user',
            'content': input_text
        }]
    
# print(prompt_img('What is in this image?', path))
# print(prompt('What is in this image?', ))

# %%
from ollama import chat, ChatResponse

message = prompt_img('Extract the groseries and price information from the next image:', path_img1)
response = chat(model='llama3.2-vision', messages=message)

print(response['message']['content'])
# Out:
# The following is a list of grocery items and their prices as shown on the receipt:
#
# 1. 5kg bagged Unsalted butter (UN) - $5,400
# 2. 6kg bagged salted butter (UN) - $5,490
# 3. 500g bagged milk powder (UN) - $4,950
# 4. 800g box of cereal (UN) - $7,700
# 5. 1L bottle of cooking oil (UN) - $6,900
# 6. 1kg pack of bacon (UN) - $9,500
# 7. 400g pack of sausage (UN) - $8,750
# 8. 2kg pack of ground beef (UN) - $10,850
# 9. 1kg pack of chicken breast (UN) - $11,950
#
# These prices are in Colombian pesos and may not reflect the current market price due to fluctuations in exchange rates and other factors.

# %%
# %%time
prompt = """Eres un experto en extraer datos de facturas en español (COP). Analiza la imagen y extrae:

1. **Tienda**: Nombre del establecimiento (parte superior).
2. **Fecha**: Fecha de emisión en formato DD/MM/YYYY (sección de validación o encabezado).
3. **Artículos y precios**: Lista de productos con la siguiente estructura:
   ```json
   [
       {
           "item": "Nombre del producto",
           "quantity": "Cantidad",
           "price": "Precio unitario",
           "total": "Precio total"
       }
   ]"""

message = prompt_img(prompt, path_img1)
response = chat(model='llama3.2-vision', messages=message)

print(response['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# File <timed exec>:17
#
# File /usr/local/lib/python3.10/dist-packages/ollama/_client.py:332, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     288 def chat(
#     289   self,
#     290   model: str = '',
#    (...)
#     297   keep_alive: Optional[Union[float, str]] = None,
#     298 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     299   """
#     300   Create a chat response using the requested model.
#     301
#    (...)
#     330   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     331   """
# --> 332   return self._request(
#     333     ChatResponse,
#     334     'POST',
#     335     '/api/chat',
#     336     json=ChatRequest(
#     337       model=model,
#     338       messages=[message for message in _copy_messages(messages)],
#     339       tools=[tool for tool in _copy_tools(tools)],
#     340       stream=stream,
#     341       format=format,
#     342       options=options,
#     343       keep_alive=keep_alive,
#     344     ).model_dump(exclude_none=True),
#     345     stream=stream,
#     346   )
#
# File /usr/local/lib/python3.10/dist-packages/ollama/_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /usr/local/lib/python3.10/dist-packages/ollama/_client.py:122, in Client._request_raw(self, *args, **kwargs)
#     120   r.raise_for_status()
#     121 except httpx.HTTPStatusError as e:
# --> 122   raise ResponseError(e.response.text, e.response.status_code) from None
#     123 return r
#
# ResponseError: POST predict: Post "http://127.0.0.1:36161/completion": EOF

# %%
# %%time
prompt = """Provide a complete OCR over the following image"""

message = prompt_img(prompt, path_img1)
response = chat(model='llama3.2-vision', messages=message)

print(response['message']['content'])
